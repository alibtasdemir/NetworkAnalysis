# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
np.random.seed(123)
import os

# %%
def corr_matrix(file, out=False):
    folder = "__Random_Features"
    data = pd.read_csv(os.path.join(folder, file))
    
    labels = data.iloc[:,-1]
    data = data.iloc[:, 2:-35]
    
    corr = data.corr()
    
    if out:
        print(corr)
    
    return corr

# %% [markdown]
# # bn-macaque-rhesus_brain_2

# %%
corr = corr_matrix("features_random_bn-macaque-rhesus_brain_2_final.csv")

# %%
sns.heatmap(corr)

# %% [markdown]
# # bn-mouse_brain_1

# %%
corr = corr_matrix("features_random_bn-mouse_brain_1_final.csv")

# %%
sns.heatmap(corr)

# %% [markdown]
# # ENZYMES_g300

# %%
sns.heatmap(corr_matrix("features_random_ENZYMES_g300_final.csv"))

# %% [markdown]
# # ENZYMES_g540

# %%
sns.heatmap(corr_matrix("features_random_ENZYMES_g540_final.csv"))

# %% [markdown]
# # soc-dolphins

# %%
sns.heatmap(corr_matrix("features_random_soc-dolphins_final.csv"))

# %% [markdown]
# # soc-firm-hi-tech

# %%
sns.heatmap(corr_matrix("features_random_soc-firm-hi-tech_final.csv"))

# %%
files = ["features_random_bio-celegans-dir_final.csv", "features_random_bn-macaque-rhesus_brain_2_final.csv", 
         "features_random_bn-mouse_brain_1_final.csv", "features_random_ENZYMES_g300_final.csv", 
        "features_random_ENZYMES_g540_final.csv", "features_random_soc-dolphins_final.csv", "features_random_soc-firm-hi-tech_final.csv"]

# %%
for file in files:
    corr = corr_matrix(file, out=False)
    print(file)
    fig, ax = plt.subplots(figsize=(11,11))
    sns.heatmap(corr, vmax=1.0, center=0, fmt='.2f',
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70})
    plt.show();
# Out:
# features_random_bio-celegans-dir_final.csv
# features_random_bn-macaque-rhesus_brain_2_final.csv
# features_random_bn-mouse_brain_1_final.csv
# features_random_ENZYMES_g300_final.csv
# features_random_ENZYMES_g540_final.csv
# features_random_soc-dolphins_final.csv
# features_random_soc-firm-hi-tech_final.csv
